# %%
import matplotlib.pyplot as plt

from model import Model

# %%
mod = Model()
mod.load_model('saved_models/test_generate_21_f_256_1024_o256_e20')

# %%
d = mod.predict_from_latex('predict_latex/4.tex')

# %%
import pandas as pd
pd.DataFrame(list(d.items()), columns=["text", "predict"])
# Out:
#                                                  text   predict
# 0   a4paper,10pt beamer T1,plmath polski cp1250 in...  1.000000
# 1                Niech  m 0  bêdzie liczb¹ ca³kowit¹.  1.000000
# 2                    Doln¹ silni¹  nazywamy wyra¿enie  1.000000
# 3                    Górn¹ silni¹  nazywamy wyra¿enie  1.000000
# 4   Wyra¿enie  x^ m  czytamy ,, x  do  m -tej ubyw...  1.000000
# 5   Przyk³ad 5^ 3 =5 4 3=60 5^ 3 =5 6 7=210 4^ 5 =...  1.000000
# 6       Definicja (liczby Stirlinga drugiego rodzaju)  1.000000
# 7   Symbol  n  k (czyt.  k  podzbiorów  n ) oznacz...  1.000000
# 8   Liczby Stirlinga drugiego rodzaju wystêpuj¹ cz...  1.000000
# 9                              Wyznacz wartoœæ  4 2 .  0.999999
# 10  Wyznaczymy liczbê podzia³ów zbioru czterolemen...  1.000000
# 11                                    Zatem  4 2 =7 .  1.000000
# 12           Wartoœci  n  k  dla ma³ych wartoœci  k :  1.000000
# 13                                              k=0 .  0.999931
# 14  Przyjmujemy, ¿e  0 0 =1 . Je¿eli  n>0  to, ocz...  1.000000
# 15                                              k=1 .  0.999868
# 16  Mamy  0 1 =0 . Dla  n>0  istnieje dok³adnie je...  1.000000
# 17                                              k=2 .  0.999098
# 18  Oczywiœcie  0 2 =0 . Za³ó¿my, ¿e  n>0 . Chcemy...  1.000000
# 19              Wartoœci  n  k  dla ma³ych  n  i  k :  1.000000
# 20                                             Uwaga!  0.999999
# 21  W przypadku, gdy  n 0  i  k<0  zak³adamy, ¿e  ...  1.000000
# 22                                        Twierdzenie  0.999995
# 23          Dla  n>0  zachodzi zale¿noœæ rekurencyjna  1.000000
# 24                                      Dowód.  (1/2)  1.000000
# 25  Niech  S= \{ a_1,a_2, ,a_n \} . Okreœlimy licz...  1.000000
# 26  W pierwszym przypadku mamy  n-1 k-1  mo¿liwoœc...  1.000000
# 27                                      Dowód.  (2/2)  1.000000
# 28  W drugim przypadku mamy  n-1  k  mo¿liwoœci po...  1.000000
# 29                                        Ostatecznie  0.999995
# 30                  Trójk¹t Stirlinga dla podzbiorów:  1.000000
# 31                                   Zatem  4 2 =11 .  1.000000
# 32                                 exampleblock frame  0.999997
# 33  Podobnie jak w przypadku liczb Stirlinga drugi...  1.000000
# 34  Oczywiœcie  0 1 =0 . Pamiêtamy, ¿e zbiór  n -e...  1.000000
# 35  Poni¿szy dowód jest modyfikacj¹ wczeœniej prze...  1.000000
# 36  Niech  S= \{ a_1,a_2, ,a_n \} . Okreœlimy licz...  1.000000
# 37  W pierwszym przypadku mamy  n-1 k-1  mo¿liwoœc...  1.000000
# 38  W drugim przypadku mamy  n-1  k  mo¿liwoœci po...  1.000000
# 39                       Trójk¹t Stirlinga dla cykli:  1.000000
# 40  Zauwa¿my, ¿e  n  k  oznacza liczbê permutacji ...  1.000000
# 41                                           Przyk³ad  0.999937
# 42  Zapisz w postaci ogólnej wielomiany  x^ s  dla...  1.000000
# 43  Jak powinno wygl¹daæ uogólnienie zaobserwowany...  0.999988
# 44                                               Wzór  0.999995
# 45  zachodzi dla ka¿dej liczby ca³kowitej dodatnie...  1.000000
# 46  Zauwa¿my, ¿e jak w powy¿szym wzorze podstawimy...  1.000000
# 47  Dowód powy¿szego twierdzenia mo¿na przeprowadz...  1.000000
# 48  Zale¿noœci miêdzy liczbami Strilinga pierwszeg...  1.000000
# 49  Zauwa¿my, ¿e liczba cykli musi byæ co najmniej...  1.000000
# 50             dla ca³kowitych nieujemnych  n  i  k .  1.000000
# 51                   Zachodz¹ tzw.   wzory inwersji :  0.999999
# 52                                  Je¿eli  m  n , to  0.999979
# 53  n  k  --- liczba  k -elementowych podzbiorów z...  1.000000
# 54  n  k  --- liczba podzia³ów  n -elementowego zb...  1.000000
# 55  n  k  --- liczba permutacji  n -elementowego z...  1.000000
# 56  Liczby Stirlinga pierwszego rodzaju nazywane s...  1.000000
# 57                                           document  0.999913

# %%
d.values()
# Out:
# dict_values([np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(0.99999905), np.float32(1.0), np.float32(0.99999994), np.float32(1.0), np.float32(0.9999306), np.float32(1.0), np.float32(0.99986833), np.float32(1.0), np.float32(0.999098), np.float32(1.0), np.float32(1.0), np.float32(0.99999905), np.float32(0.9999995), np.float32(0.9999951), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(0.99999994), np.float32(1.0), np.float32(0.9999947), np.float32(1.0), np.float32(1.0), np.float32(0.9999975), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(0.9999373), np.float32(1.0), np.float32(0.9999881), np.float32(0.9999952), np.float32(1.0), np.float32(1.0), np.float32(1.0), np.float32(0.9999998), np.float32(1.0), np.float32(0.9999998), np.float32(0.99999934), np.float32(0.9999792), np.float32(0.99999994), np.float32(0.99999994), np.float32(1.0), np.float32(1.0), np.float32(0.9999129)])

# %%
# Out:
# Notebook successfully converted to raport.html

# %%
import zipfile
import subprocess
import os
import  matplotlib.pyplot as plt
import seaborn as sns
import nbformat
from nbconvert import HTMLExporter
from nbconvert.preprocessors import ExecutePreprocessor
import webbrowser
import shutil

class ReportGenerator:
    def __init__(self):
        self.report_latex_exists = False
        self.report_html_exists = False
        self.tex_pattern = 'report_pattern.tex'
        self.tex_output_folder = "reports"
        self.tex_png_output_folder = "elements"
        self.tex_out_file_name = "report.tex"
        self.html_pattern = 'report_pattern.ipynb'
        self.html_out_file_name = "report.html"

    def generate_plots_for_latex(self,data):
        plt.plot([i for i in range(len(data))],data)
        plt.savefig(os.path.join(self.tex_output_folder,self.tex_png_output_folder,"plot0.png"))
        ###
        plt.figure(figsize=(8, 6))
        sns.histplot(data, bins=8, kde=True, color='blue')
        plt.xlim(min(data), max(data))
        plt.xlabel('a', fontsize=12)
        plt.ylabel('b', fontsize=12)
        plt.title('c', fontsize=14)
        plt.savefig(os.path.join(self.tex_output_folder,self.tex_png_output_folder,"plot1.png"))

    def generate_latex_report(self,data,results):
        self.report_latex_exists = False
        with open(self.tex_pattern, 'r') as f:
            tex = f.read()
        for input,text in enumerate(data):
            tex = tex.replace(f"Input-nr-{input}",text)
        for i in range(2):
            tex = tex.replace(f"Plot-nr-{i}",self.tex_png_output_folder+f"/plot{i}.png")
        os.makedirs(os.path.join(self.tex_output_folder,self.tex_png_output_folder), exist_ok=True)
        self.generate_plots_for_latex(results)
        with open(os.path.join(self.tex_output_folder,self.tex_out_file_name), 'w') as f:
            f.write(tex)
        # To PDF
        try:
            result = subprocess.run(
                ["pdflatex", self.tex_out_file_name],
                cwd=self.tex_output_folder,
                check=True,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
        except subprocess.CalledProcessError as e:
            print(f"Error occurred during LaTeX compilation: {e}")
        self.report_latex_exists = True

    def generate_html_report(self):

        with open(self.html_pattern, 'r', encoding='utf-8') as f:
            notebook_content = nbformat.read(f, as_version=4)

        data_to_pass = {"data": ["24.01.2025","13:34","test.tex","green", "40.0", "123", "54" ], "numbers": [42,12,34]}
        notebook_content.cells[1].source = f"data = {data_to_pass}"

        execute_preprocessor = ExecutePreprocessor(timeout=600, kernel_name='python3')
        try:
            execute_preprocessor.preprocess(notebook_content, {'metadata': {'path': './'}})
        except Exception as e:
            print(f"Error during execution: {e}")
            return

        html_exporter = HTMLExporter()
        html_exporter.exclude_input = True
        html_exporter.exclude_input_prompt = True  #

        (html_body, _) = html_exporter.from_notebook_node(notebook_content)

        with open(os.path.join( self.tex_output_folder,self.html_out_file_name), 'w', encoding='utf-8') as f:
            f.write(html_body)

    def open_latex_report(self):
        try:
            os.startfile(os.path.join(self.tex_output_folder,os.path.splitext(self.tex_out_file_name)[0] + ".pdf"))
        except Exception as e:
            print(f"Failed to open PDF: {e}")

    def open_html_report(self):
         webbrowser.open(os.path.join( self.tex_output_folder,self.html_out_file_name))

    def download_latex_report(self,path):
        if self.report_latex_exists:
            try:
                folder_to_zip = self.tex_png_output_folder
                folder_path = os.path.join(self.tex_output_folder, folder_to_zip)
                with zipfile.ZipFile(path, 'w', zipfile.ZIP_DEFLATED) as zipf:
                    for file_path in [self.tex_out_file_name, os.path.splitext(self.tex_out_file_name)[0] + ".pdf"]:
                        full_file_path = os.path.join(self.tex_output_folder, file_path)
                        if os.path.exists(full_file_path):
                            zip_element = os.path.relpath(full_file_path, start=self.tex_output_folder)
                            zipf.write(full_file_path, zip_element)
                    if os.path.exists(folder_path):
                        for root, _, files in os.walk(folder_path):
                            for file in files:
                                file_path = os.path.join(root, file)
                                zip_element = os.path.relpath(file_path, start=self.tex_output_folder)
                                zipf.write(file_path, zip_element)
            except Exception as e:
                print(f"Error while zipping folder: {e}")

    def download_html_report(self,path):
        shutil.copy(os.path.join( self.tex_output_folder,self.html_out_file_name), path)

# %%
r = ReportGenerator()
# r.generate_latex_report( data = ["24.01.2025","13:34","test.tex","green", "40.0", "123", "54" ], results= [0.0,0.1,0.2,0.1,0.6,0.9,0.8,0.1,1.0])
# r.open_latex_report()
# r.download_latex_report("C:\\Users\\domin\\Desktop\\STUDIA\\Sem. V\\Inżynieria_Oprogramowania\\Skradzione-Wzory\\a.zip")
r.generate_html_report()
r.open_html_report()
#r.download_html_report("C:\\Users\\domin\\Desktop\\STUDIA\\Sem. V\\Inżynieria_Oprogramowania\\Skradzione-Wzory")

# %%
r = ReportGenerator()
r.generate_latex_report( data = ["24.01.2025","13:34","test.tex","green", "40.0", "123", "54" ], results= [0.0,0.1,0.2,0.1,0.6,0.9,0.8,0.1,1.0])
r.download_latex_report("C:\\Users\\domin\\Desktop\\STUDIA\\Sem. V\\Inżynieria_Oprogramowania\\Skradzione-Wzory\\a.zip")
